# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
costum_colors = ["#232F3E","#FEBD69","#11999E","#40514E","#E4F9F5","#37475A"]
sns.set_palette(sns.color_palette(costum_colors))
sns.palplot(costum_colors)

# %%
books = "output/combined_book2.csv"
books_df = pd.read_csv(books)
books_df.head()
# Out:
#    rank primary_isbn13  publisher                         title  \
# 0    11  9781982168018    Gallery                         TASTE
# 1     8  9780062888341     Harper  THE STRANGER IN THE LIFEBOAT
# 2    10  9780385547932  Doubleday                   TO PARADISE
# 3    11  9780593465066     Viking         CALL US WHAT WE CARRY
# 4    12  9781982168438   Scribner             CLOUD CUCKOO LAND
#
#              author              category    pub_date Amazon Product ID  \
# 0     Stanley Tucci  Hardcover Nonfiction  2022-02-06        1982168013
# 1       Mitch Albom     Hardcover Fiction  2022-02-06        006288834X
# 2  Hanya Yanagihara     Hardcover Fiction  2022-02-06        B091XWH5T2
# 3     Amanda Gorman     Hardcover Fiction  2022-02-06        0593465067
# 4     Anthony Doerr     Hardcover Fiction  2022-02-06        B08TRMSR3Z
#
#    Amazon Rating  Amazon Rating Total  Amazon Price
# 0            4.7               3118.0         14.00
# 1            4.6               9966.0         15.07
# 2            4.2                204.0         14.99
# 3            4.9               1794.0         14.53
# 4            4.5               8792.0         15.99

# %%
len(books_df)
# Out:
# 860

# %%
books_df.columns
# Out:
# Index(['rank', 'primary_isbn13', 'publisher', 'title', 'author', 'category',
#        'pub_date', 'Amazon Product ID', 'Amazon Rating', 'Amazon Rating Total',
#        'Amazon Price'],
#       dtype='object')

# %%
books_df.columns = ['NYT Ranking', 'ISBN', 'Publisher', 'Title', 'Author', 'Book Category',
       'NYT Pub Date', 'Amazon Product ID', 'Num of Amz Ratings', 'Amazon Rating Total',
       'Amazon Price']
books_df
# Out:
#      NYT Ranking           ISBN                Publisher  \
# 0             11  9781982168018                  Gallery
# 1              8  9780062888341                   Harper
# 2             10  9780385547932                Doubleday
# 3             11  9780593465066                   Viking
# 4             12  9781982168438                 Scribner
# ..           ...            ...                      ...
# 855           18  9780312547745       St. Martin's Press
# 856           15  9780399157707            Penguin Group
# 857           12  9781439152805              Atria Books
# 858            2  9780345504982  Random House Publishing
# 859           20  9780307886279         Crown Publishing
#
#                                       Title  \
# 0                                     TASTE
# 1              THE STRANGER IN THE LIFEBOAT
# 2                               TO PARADISE
# 3                     CALL US WHAT WE CARRY
# 4                         CLOUD CUCKOO LAND
# ..                                      ...
# 855  THE WALKING DEAD, RISE OF THE GOVERNOR
# 856                               MAD RIVER
# 857                       THE SECRET KEEPER
# 858                              THE TWELVE
# 859     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                 Author              Book Category  \
# 0                        Stanley Tucci       Hardcover Nonfiction
# 1                          Mitch Albom          Hardcover Fiction
# 2                     Hanya Yanagihara          Hardcover Fiction
# 3                        Amanda Gorman          Hardcover Fiction
# 4                        Anthony Doerr          Hardcover Fiction
# ..                                 ...                        ...
# 855  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 856                      John Sandford     Combined Print Fiction
# 857                        Kate Morton     Combined Print Fiction
# 858                      Justin Cronin     Combined Print Fiction
# 859                       Mindy Kaling  Combined Print Nonfiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 0     2022-02-06        1982168013                 4.7               3118.0
# 1     2022-02-06        006288834X                 4.6               9966.0
# 2     2022-02-06        B091XWH5T2                 4.2                204.0
# 3     2022-02-06        0593465067                 4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z                 4.5               8792.0
# ..           ...               ...                 ...                  ...
# 855   2012-11-04        B009RFHNB8                 4.5                930.0
# 856   2012-11-04        B0085DP6EY                 4.6               3011.0
# 857   2012-11-04        B009R5Q51W                 4.5               7219.0
# 858   2012-11-04        B009RFGP8K                 4.5               4496.0
# 859   2012-11-04        B0061YXJO8                 4.4               5841.0
#
#      Amazon Price
# 0           14.00
# 1           15.07
# 2           14.99
# 3           14.53
# 4           15.99
# ..            ...
# 855          0.00
# 856          9.99
# 857          0.00
# 858          0.00
# 859          0.00
#
# [860 rows x 11 columns]

# %%
data_new1 = books_df.copy()                              
data_new1 = data_new1.replace(r'^s*$', float('NaN'), regex = True)  
data_new1_df = pd.DataFrame(data_new1)
data_new1_df
# Out:
#      NYT Ranking           ISBN                Publisher  \
# 0             11  9781982168018                  Gallery
# 1              8  9780062888341                   Harper
# 2             10  9780385547932                Doubleday
# 3             11  9780593465066                   Viking
# 4             12  9781982168438                 Scribner
# ..           ...            ...                      ...
# 855           18  9780312547745       St. Martin's Press
# 856           15  9780399157707            Penguin Group
# 857           12  9781439152805              Atria Books
# 858            2  9780345504982  Random House Publishing
# 859           20  9780307886279         Crown Publishing
#
#                                       Title  \
# 0                                     TASTE
# 1              THE STRANGER IN THE LIFEBOAT
# 2                               TO PARADISE
# 3                     CALL US WHAT WE CARRY
# 4                         CLOUD CUCKOO LAND
# ..                                      ...
# 855  THE WALKING DEAD, RISE OF THE GOVERNOR
# 856                               MAD RIVER
# 857                       THE SECRET KEEPER
# 858                              THE TWELVE
# 859     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                 Author              Book Category  \
# 0                        Stanley Tucci       Hardcover Nonfiction
# 1                          Mitch Albom          Hardcover Fiction
# 2                     Hanya Yanagihara          Hardcover Fiction
# 3                        Amanda Gorman          Hardcover Fiction
# 4                        Anthony Doerr          Hardcover Fiction
# ..                                 ...                        ...
# 855  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 856                      John Sandford     Combined Print Fiction
# 857                        Kate Morton     Combined Print Fiction
# 858                      Justin Cronin     Combined Print Fiction
# 859                       Mindy Kaling  Combined Print Nonfiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 0     2022-02-06        1982168013                 4.7               3118.0
# 1     2022-02-06        006288834X                 4.6               9966.0
# 2     2022-02-06        B091XWH5T2                 4.2                204.0
# 3     2022-02-06        0593465067                 4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z                 4.5               8792.0
# ..           ...               ...                 ...                  ...
# 855   2012-11-04        B009RFHNB8                 4.5                930.0
# 856   2012-11-04        B0085DP6EY                 4.6               3011.0
# 857   2012-11-04        B009R5Q51W                 4.5               7219.0
# 858   2012-11-04        B009RFGP8K                 4.5               4496.0
# 859   2012-11-04        B0061YXJO8                 4.4               5841.0
#
#      Amazon Price
# 0           14.00
# 1           15.07
# 2           14.99
# 3           14.53
# 4           15.99
# ..            ...
# 855          0.00
# 856          9.99
# 857          0.00
# 858          0.00
# 859          0.00
#
# [860 rows x 11 columns]

# %%
data_new2 = data_new1.copy()                          
data_new2.dropna(inplace = True)                     
data_new2_df = pd.DataFrame(data_new2)
data_new2_df
# Out:
#      NYT Ranking           ISBN                Publisher  \
# 0             11  9781982168018                  Gallery
# 1              8  9780062888341                   Harper
# 2             10  9780385547932                Doubleday
# 3             11  9780593465066                   Viking
# 4             12  9781982168438                 Scribner
# ..           ...            ...                      ...
# 855           18  9780312547745       St. Martin's Press
# 856           15  9780399157707            Penguin Group
# 857           12  9781439152805              Atria Books
# 858            2  9780345504982  Random House Publishing
# 859           20  9780307886279         Crown Publishing
#
#                                       Title  \
# 0                                     TASTE
# 1              THE STRANGER IN THE LIFEBOAT
# 2                               TO PARADISE
# 3                     CALL US WHAT WE CARRY
# 4                         CLOUD CUCKOO LAND
# ..                                      ...
# 855  THE WALKING DEAD, RISE OF THE GOVERNOR
# 856                               MAD RIVER
# 857                       THE SECRET KEEPER
# 858                              THE TWELVE
# 859     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                 Author              Book Category  \
# 0                        Stanley Tucci       Hardcover Nonfiction
# 1                          Mitch Albom          Hardcover Fiction
# 2                     Hanya Yanagihara          Hardcover Fiction
# 3                        Amanda Gorman          Hardcover Fiction
# 4                        Anthony Doerr          Hardcover Fiction
# ..                                 ...                        ...
# 855  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 856                      John Sandford     Combined Print Fiction
# 857                        Kate Morton     Combined Print Fiction
# 858                      Justin Cronin     Combined Print Fiction
# 859                       Mindy Kaling  Combined Print Nonfiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 0     2022-02-06        1982168013                 4.7               3118.0
# 1     2022-02-06        006288834X                 4.6               9966.0
# 2     2022-02-06        B091XWH5T2                 4.2                204.0
# 3     2022-02-06        0593465067                 4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z                 4.5               8792.0
# ..           ...               ...                 ...                  ...
# 855   2012-11-04        B009RFHNB8                 4.5                930.0
# 856   2012-11-04        B0085DP6EY                 4.6               3011.0
# 857   2012-11-04        B009R5Q51W                 4.5               7219.0
# 858   2012-11-04        B009RFGP8K                 4.5               4496.0
# 859   2012-11-04        B0061YXJO8                 4.4               5841.0
#
#      Amazon Price
# 0           14.00
# 1           15.07
# 2           14.99
# 3           14.53
# 4           15.99
# ..            ...
# 855          0.00
# 856          9.99
# 857          0.00
# 858          0.00
# 859          0.00
#
# [860 rows x 11 columns]

# %%
data_new2_df.columns
# Out:
# Index(['NYT Ranking', 'ISBN', 'Publisher', 'Title', 'Author', 'Book Category',
#        'NYT Pub Date', 'Amazon Product ID', 'Num of Amz Ratings',
#        'Amazon Rating Total', 'Amazon Price'],
#       dtype='object')

# %%
data_new2_df.duplicated(subset=['ISBN']).sum()
# Out:
# 38

# %%
data_new2_df.drop_duplicates(subset=['ISBN'],inplace=True)

# %%
# What is the 10 top  rating books and Authors with the most star rating?

# %%
#Top Rating Books
Top_Rating_Books_df=data_new2.sort_values(by="Num of Amz Ratings", ascending=False)\
[["Book Category", "Title", "Author","Num of Amz Ratings","Amazon Rating Total"]].head(10)


Top_Rating_Books_df
# Out:
#                  Book Category                     Title  \
# 49   Combined Print Nonfiction                     QUIET
# 632  Combined Print Nonfiction                     QUIET
# 426          E-Book Nonfiction              HUNGRY HEART
# 254       Hardcover Nonfiction          THE BOMBER MAFIA
# 221          Hardcover Fiction       ROCK PAPER SCISSORS
# 132          Hardcover Fiction         PROJECT HAIL MARY
# 106       Hardcover Nonfiction          AMERICAN MARXISM
# 245       Hardcover Nonfiction  THE AUTHORITARIAN MOMENT
# 626  Combined Print Nonfiction                 SUM IT UP
# 86        Hardcover Nonfiction                RED-HANDED
#
#                                   Author  Num of Amz Ratings  \
# 49                            Susan Cain                 5.0
# 632                           Susan Cain                 5.0
# 426                      Jennifer Weiner                 5.0
# 254                     Malcolm Gladwell                 5.0
# 221                         Alice Feeney                 5.0
# 132                            Andy Weir                 5.0
# 106                        Mark R. Levin                 4.9
# 245                          Ben Shapiro                 4.9
# 626  Pat Head Summitt with Sally Jenkins                 4.9
# 86                       Peter Schweizer                 4.9
#
#      Amazon Rating Total
# 49                   3.0
# 632                  3.0
# 426                  8.0
# 254                  1.0
# 221                 10.0
# 132                  2.0
# 106              26872.0
# 245               2982.0
# 626               1134.0
# 86                  45.0

# %%
### Observation:It looks like the 5 star books haven't been popular in Amazon yet.

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="Title", y="Amazon Rating Total", data=Top_Rating_Books_df,hue='Num of Amz Ratings',palette=costum_colors,saturation=1)
# Out:
# <AxesSubplot:xlabel='Title', ylabel='Amazon Rating Total'>

# %%
### What is the Average price of books in every categories?

# %%
# price_average for every category
price_mean=data_new2.groupby('Book Category').mean()["Amazon Price"].to_frame().sort_values(by='Amazon Price',
ascending=False)
price_mean
# Out:
#                            Amazon Price
# Book Category
# Hardcover Nonfiction          15.727636
# Hardcover Fiction             13.254592
# Audio Fiction                 11.960000
# Combined Print Nonfiction     10.554640
# Combined Print Fiction         7.719464
# E-Book Nonfiction              7.130423
# E-Book Fiction                 6.935802
# Audio Nonfiction               0.000000

# %%
# Price Average per Categories
price_mean.plot(kind="bar", figsize=(20,3),facecolor='#FEBD69',edgecolor='#232F3E')

# Set a title for the chart
plt.title("Price Average per Categories")
plt.ylabel('Average Price')
plt.show()
plt.tight_layout()

# %%
### The number of books in every categories

# %%
# Rating Average per Category 
plt.figure(figsize=(15,7))
total_categories=data_new2['Book Category'].value_counts().to_dict()
categories=list(total_categories.keys())[:-2]
totals_values=list(total_categories.values())[:-2]

colors = ["#232F3E","#FEBD69","#40514E","#11999E","#E4F9F5","#37475A"]
explode = (0.3,0,0,0,0,0)


plt.pie(totals, explode=explode, labels=categories, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=200)

plt.axis("equal")


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s3/lg_v6j6j039ckm9ct5vb081w0000gn/T/ipykernel_4830/825694420.py in <module>
#       9
#      10
# ---> 11 plt.pie(totals, explode=explode, labels=categories, colors=colors,
#      12         autopct="%1.1f%%", shadow=True, startangle=200)
#      13
#
# NameError: name 'totals' is not defined

# %%
### What is the Average rated books in every category?

# %%
avg_rate_df=data_new2_df.groupby('Book Category').mean()['Amazon Rating Total'].sort_values(ascending=False)
avg_rate_df.to_frame()
# Out:
#                            Amazon Rating Total
# Book Category
# Audio Fiction                     24740.000000
# Hardcover Fiction                 10675.836735
# Audio Nonfiction                   8828.000000
# Combined Print Fiction             5488.456954
# E-Book Fiction                     5040.000000
# Hardcover Nonfiction               4173.568807
# Combined Print Nonfiction          3203.681416
# E-Book Nonfiction                  2977.571429

# %%
plt.figure(figsize=(15,7))

avg_rate_df.plot(kind='bar',facecolor='#11999E',edgecolor='#37475A')
plt.title(" Average Amazon Rating Total per Categories",fontsize= 15,pad=10,fontweight="bold")
plt.ylabel('Average Amazon Rating Total')
#plt.savefig('images/?.png')
plt.gcf().set_size_inches(20, 10)
plt.show()

# %%
### What is the range of book rate in every category

# %%
#Creat bins
bins = [ 2, 3, 4 , 5]
# Create the names for the four bins
group_names = ["<3", '3-4',"4-5"]
data_rate_baced_df=data_new2_df.copy()
data_rate_baced_df['Num of Amz Ratings_']=pd.cut(data_rate_baced_df['Num of Amz Ratings'], bins, labels=group_names,include_lowest=True)
data_rate_baced_df1=data_rate_baced_df.groupby(['Book Category','Num of Amz Ratings_']).count()['Amazon Rating Total'].reset_index().pivot_table(values='Amazon Rating Total',index=['Book Category'],columns=['Num of Amz Ratings_'])
data_rate_baced_df1
# Out:
# Num of Amz Ratings_        <3  3-4  4-5
# Book Category
# Audio Fiction               0    0    4
# Audio Nonfiction            0    0    1
# Combined Print Fiction      0   11  140
# Combined Print Nonfiction   0    7  106
# E-Book Fiction              0    9  197
# E-Book Nonfiction           0    5  135
# Hardcover Fiction           0   11   87
# Hardcover Nonfiction        1    2  106

# %%
plt.figure(figsize=(20,10))
data_rate_baced_df1.plot.bar()
plt.title("Books per Categories based on rating",fontsize= 15,pad=10,fontweight="bold")
plt.gcf().set_size_inches(20, 10)

# %%
plt.figure(figsize=(20,10))
sns.barplot(x="Book Category", y="Amazon Rating Total",hue='Num of Amz Ratings_', data=data_rate_baced_df,
            ci=None,palette=costum_colors)
plt.title("Amazon Rating Total per Categories",fontsize= 15,pad=10,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Amazon Rating Total per Categories')

# %%
### Which book has the lowest number of rating

# %%
data_new2.loc[data_new2['Num of Amz Ratings']<3]
# Out:
#      NYT Ranking           ISBN         Publisher  Title  \
# 112            9  9781982182915  Simon & Schuster  PERIL
#
#                             Author         Book Category NYT Pub Date  \
# 112  Bob Woodward and Robert Costa  Hardcover Nonfiction   2022-01-23
#
#     Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  Amazon Price
# 112        9124143693                 2.5                  2.0         64.99

# %%
### Top 10 authers with most books in all categories?

# %%
Top_authers=data_new2['Author'].value_counts().head(10)
Top_authers
# Out:
# Danielle Steel      13
# Nicholas Sparks      8
# David Baldacci       8
# Debbie Macomber      7
# Michael Connelly     7
# John Grisham         6
# Nora Roberts         6
# Stuart Woods         5
# James Patterson      5
# Kristin Hannah       5
# Name: Author, dtype: int64

# %%
Top_authers_list=[data_new2.loc[data_new2['Author']==i] for i in Top_authers.index]
Top_authers_df=pd.concat(Top_authers_list)
Top_authers_df
# Out:
#      NYT Ranking           ISBN     Publisher            Title  \
# 56             8  9780425285350     Delacorte     THE MISTRESS
# 104           11  9781984821584     Delacorte        INVISIBLE
# 139            8  9781984821553     Delacorte    FLYING ANGELS
# 170           15  9781984821522     Delacorte       THE BUTLER
# 235            9  9781984821492     Delacorte    COMPLICATIONS
# ..           ...            ...           ...              ...
# 96             3  9780312577216  St. Martin's         FLY AWAY
# 247           15  9781250178602  St. Martin's   THE FOUR WINDS
# 286            3  9780345459503    Ballantine   DISTANT SHORES
# 295            7  9781466850606  St. Martin's  THE NIGHTINGALE
# 512            3  9780345459527    Ballantine    SUMMER ISLAND
#
#              Author           Book Category NYT Pub Date Amazon Product ID  \
# 56   Danielle Steel          E-Book Fiction   2022-02-02        B01E2GZ5FC
# 104  Danielle Steel       Hardcover Fiction   2022-01-30        B091PJSK74
# 139  Danielle Steel       Hardcover Fiction   2021-12-12        B08XBQ7BZ9
# 170  Danielle Steel       Hardcover Fiction   2021-11-07        B08SJNJWZL
# 235  Danielle Steel       Hardcover Fiction   2021-09-19        B08LMT1RZF
# ..              ...                     ...          ...               ...
# 96   Kristin Hannah  Combined Print Fiction   2022-02-02        1250031818
# 247  Kristin Hannah       Hardcover Fiction   2021-09-05        B0882VNQKS
# 286  Kristin Hannah          E-Book Fiction   2017-01-22        B000FA64R8
# 295  Kristin Hannah          E-Book Fiction   2017-01-15        B09KQWZTHQ
# 512  Kristin Hannah          E-Book Fiction   2016-09-11        B000FC1KKC
#
#      Num of Amz Ratings  Amazon Rating Total  Amazon Price
# 56                  4.5               2652.0          6.99
# 104                 4.6               2502.0         14.99
# 139                 4.6               4759.0         14.99
# 170                 4.5               5437.0         14.99
# 235                 4.4               5458.0         14.99
# ..                  ...                  ...           ...
# 96                  4.5              13801.0         10.67
# 247                 4.5              90123.0          0.00
# 286                 4.4               4719.0          8.99
# 295                 4.5                 14.0          0.00
# 512                 4.5               6340.0          7.99
#
# [70 rows x 11 columns]

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Author',data=Top_authers_df,hue='Book Category',palette=costum_colors)
plt.legend(loc='upper right')
plt.xticks(rotation="vertical")
plt.title('Top 10 authers with most books in all categories',fontsize= 15,pad=10,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Top 10 authers with most books in all categories')

# %%
### What is most popular books in every categories

# %%
Top_rating_books_in_every_ctg=data_new2.groupby(['Book Category']).max()[['Amazon Rating Total']]
Top_rating_books_in_every_ctg
# Out:
#                            Amazon Rating Total
# Book Category
# Audio Fiction                          25110.0
# Audio Nonfiction                        8828.0
# Combined Print Fiction                 63773.0
# Combined Print Nonfiction              32697.0
# E-Book Fiction                         87948.0
# E-Book Nonfiction                      51560.0
# Hardcover Fiction                     132607.0
# Hardcover Nonfiction                   59410.0

# %%
#Top rating books in every categories
Top_rating_books_list=[data_new2.loc[data_new2['Amazon Rating Total']==i] for i in Top_rating_books_in_every_ctg['Amazon Rating Total'] ]
Top_rating_books_df=pd.concat(Top_rating_books_list)
Top_rating_books_df.set_index('Book Category')
# Out:
#                            NYT Ranking           ISBN  \
# Book Category
# Audio Fiction                        7  DORORIG000029
# Audio Fiction                       11  DORORIG000747
# Audio Nonfiction                    13  9780786581795
# Combined Print Fiction               9  9780307588364
# Combined Print Nonfiction           14  9781400064168
# E-Book Fiction                      15  9780698185395
# E-Book Nonfiction                    5  9780062316103
# Hardcover Fiction                    1  9780525559474
# Hardcover Nonfiction                11  9780399590504
#
#                                          Publisher                  Title  \
# Book Category
# Audio Fiction                    Audible Originals         HEAVEN'S RIVER
# Audio Fiction                    Audible Originals            THE SANDMAN
# Audio Nonfiction                     Penguin Audio    THE GREAT INFLUENZA
# Combined Print Fiction            Crown Publishing              GONE GIRL
# Combined Print Nonfiction  Random House Publishing               UNBROKEN
# E-Book Fiction                           Riverhead  THE GIRL ON THE TRAIN
# E-Book Nonfiction                           Harper                SAPIENS
# Hardcover Fiction                           Viking   THE MIDNIGHT LIBRARY
# Hardcover Nonfiction                  Random House               EDUCATED
#
#                                                Author NYT Pub Date  \
# Book Category
# Audio Fiction                         Dennis E Taylor   2020-11-01
# Audio Fiction              Neil Gaiman and Dirk Maggs   2020-10-01
# Audio Nonfiction                        John M. Barry   2020-06-01
# Combined Print Fiction                  Gillian Flynn   2013-04-28
# Combined Print Nonfiction           Laura Hillenbrand   2013-04-14
# E-Book Fiction                          Paula Hawkins   2016-12-11
# E-Book Nonfiction                   Yuval Noah Harari   2016-12-11
# Hardcover Fiction                           Matt Haig   2022-02-06
# Hardcover Nonfiction                    Tara Westover   2021-09-19
#
#                           Amazon Product ID  Num of Amz Ratings  \
# Book Category
# Audio Fiction                    B0009811TW                 4.7
# Audio Fiction                    B0009811TW                 4.7
# Audio Nonfiction                 B000F2C6Y6                 4.6
# Combined Print Fiction           B0088UT8IO                 4.1
# Combined Print Nonfiction        B004CJN7TG                 4.8
# E-Book Fiction                   1594634025                 4.1
# E-Book Nonfiction                B0741F3M7C                 4.6
# Hardcover Fiction                0525559477                 4.3
# Hardcover Nonfiction             0399590501                 4.7
#
#                            Amazon Rating Total  Amazon Price
# Book Category
# Audio Fiction                          25110.0          7.95
# Audio Fiction                          25110.0          7.95
# Audio Nonfiction                        8828.0          0.00
# Combined Print Fiction                 63773.0          0.00
# Combined Print Nonfiction              32697.0          0.00
# E-Book Fiction                         87948.0          7.48
# E-Book Nonfiction                      51560.0          0.00
# Hardcover Fiction                     132607.0         13.29
# Hardcover Nonfiction                   59410.0         13.00

# %%
### Which  books are  with  the most occurances in the Dataset?

# %%
books = data_new2['Title'].value_counts().head(11).to_dict()
books
# Out:
# {'WILD': 3,
#  'QUIET': 3,
#  'THE FORGOTTEN': 3,
#  'THE STORYTELLER': 3,
#  'A MAN CALLED OVE': 3,
#  'THE BLACK BOX': 3,
#  'A GAME OF THRONES': 3,
#  'SAFE HAVEN': 3,
#  'BETRAYAL': 3,
#  'UNSINKABLE': 3,
#  'SAY YOU WANT ME': 2}

# %%
books_df=pd.concat([data_new2.loc[data_new2['Title']==i] for i in books.keys()])
books_df.head(5)
# Out:
#      NYT Ranking           ISBN                   Publisher  Title  \
# 37             5  9780307476074                     Vintage   WILD
# 635            3  9780307476074  Knopf Doubleday Publishing   WILD
# 691           20  9780307592736  Knopf Doubleday Publishing   WILD
# 49            13  9780307352156                    Broadway  QUIET
# 632            8  9780307352156            Crown Publishing  QUIET
#
#              Author              Book Category NYT Pub Date Amazon Product ID  \
# 37   Cheryl Strayed  Combined Print Nonfiction   2022-02-02        B01NCT5R2J
# 635  Cheryl Strayed  Combined Print Nonfiction   2013-04-28        B01NCT5R2J
# 691  Cheryl Strayed  Combined Print Nonfiction   2013-03-31        0307476073
# 49       Susan Cain  Combined Print Nonfiction   2022-02-02        9123962984
# 632      Susan Cain  Combined Print Nonfiction   2013-04-28        9123962984
#
#      Num of Amz Ratings  Amazon Rating Total  Amazon Price
# 37                  4.7                  5.0         34.99
# 635                 4.7                  5.0         34.99
# 691                 4.5              21583.0          9.29
# 49                  5.0                  3.0         40.80
# 632                 5.0                  3.0         40.80

# %%
plt.figure(figsize=(20,7))
sns.countplot(x='Title',data=books_df,hue='Book Category',palette=costum_colors)
plt.title('books with the most occurances',fontsize= 15,pad=10,fontweight="bold")
plt.show()
plt.tight_layout()

# %%
### Which are the top 10 most popular books overall?

# %%
most_rated_books_df=data_new2.sort_values(by="Amazon Rating Total", ascending=False).head(10)
most_rated_books_df
# Out:
#      NYT Ranking           ISBN                   Publisher  \
# 28             1  9780525559474                      Viking
# 247           15  9781250178602                St. Martin's
# 354           15  9780698185395                   Riverhead
# 29             6  9781501171345            Simon & Schuster
# 296           10  9780062416216               HarperCollins
# 639            9  9780307588364            Crown Publishing
# 90             9  9780307588364                       Crown
# 230           11  9780399590504                Random House
# 530           14  9781501110375                       Atria
# 644           13  9780345803481  Knopf Doubleday Publishing
#
#                          Title          Author           Book Category  \
# 28        THE MIDNIGHT LIBRARY       Matt Haig       Hardcover Fiction
# 247             THE FOUR WINDS  Kristin Hannah       Hardcover Fiction
# 354      THE GIRL ON THE TRAIN   Paula Hawkins          E-Book Fiction
# 29   THE LAST THING HE TOLD ME      Laura Dave       Hardcover Fiction
# 296              THE ALCHEMIST    Paulo Coelho          E-Book Fiction
# 639                  GONE GIRL   Gillian Flynn  Combined Print Fiction
# 90                   GONE GIRL   Gillian Flynn  Combined Print Fiction
# 230                   EDUCATED   Tara Westover    Hardcover Nonfiction
# 530            IT ENDS WITH US  Colleen Hoover          E-Book Fiction
# 644       FIFTY SHADES OF GREY       E L James  Combined Print Fiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 28    2022-02-06        0525559477                 4.3             132607.0
# 247   2021-09-05        B0882VNQKS                 4.5              90123.0
# 354   2016-12-11        1594634025                 4.1              87948.0
# 29    2022-02-06        1501171348                 4.3              67771.0
# 296   2017-01-15        0062315005                 4.7              67078.0
# 639   2013-04-28        B0088UT8IO                 4.1              63773.0
# 90    2022-02-02        B0088UT8IO                 4.1              63770.0
# 230   2021-09-19        0399590501                 4.7              59410.0
# 530   2016-08-28        1501110365                 4.7              57852.0
# 644   2013-04-28        B007R07BK8                 4.0              56999.0
#
#      Amazon Price
# 28          13.29
# 247          0.00
# 354          7.48
# 29          13.50
# 296          8.89
# 639          0.00
# 90           0.00
# 230         13.00
# 530         12.79
# 644          0.00

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Title',y='Amazon Rating Total',data=most_rated_books_df,hue='Book Category',palette=costum_colors)
plt.legend(loc='upper right')
plt.xticks(rotation="vertical")
plt.title('top 10 most popular books in all categories',fontsize= 15,pad=10,fontweight="bold")
plt.show()

# %%
def main_categories(x):
    if x in ["Audio Fiction","Audio Nonfiction"]:
        return "Audio"
    
    elif x in ["Hardcover fiction","Hardcover Nonfiction","Combined Print Nonfiction","Combined Print fiction"]:
        return "printed"
    
    else:
        return "E-Book"

    
def fiction_or_not_detector(x):
    if x in ["Audio Fiction","Hardcover Fiction","Combined Print Fiction","E-Book Fiction"]:
        return "Fiction"
    
    elif x in ["Audio Nonfiction","Hardcover Nonfiction","Combined Print Nonfiction","E-Book Nonfiction"]:
        return "Nonfiction"

# %%
df=data_new2_df.copy()
df['Fic_or_NotFic']= df['Book Category'].apply(fiction_or_not_detector)
df["Main_category"]=df['Book Category'].apply(main_categories)
df
# Out:
#      NYT Ranking           ISBN                Publisher  \
# 0             11  9781982168018                  Gallery
# 1              8  9780062888341                   Harper
# 2             10  9780385547932                Doubleday
# 3             11  9780593465066                   Viking
# 4             12  9781982168438                 Scribner
# ..           ...            ...                      ...
# 855           18  9780312547745       St. Martin's Press
# 856           15  9780399157707            Penguin Group
# 857           12  9781439152805              Atria Books
# 858            2  9780345504982  Random House Publishing
# 859           20  9780307886279         Crown Publishing
#
#                                       Title  \
# 0                                     TASTE
# 1              THE STRANGER IN THE LIFEBOAT
# 2                               TO PARADISE
# 3                     CALL US WHAT WE CARRY
# 4                         CLOUD CUCKOO LAND
# ..                                      ...
# 855  THE WALKING DEAD, RISE OF THE GOVERNOR
# 856                               MAD RIVER
# 857                       THE SECRET KEEPER
# 858                              THE TWELVE
# 859     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                 Author              Book Category  \
# 0                        Stanley Tucci       Hardcover Nonfiction
# 1                          Mitch Albom          Hardcover Fiction
# 2                     Hanya Yanagihara          Hardcover Fiction
# 3                        Amanda Gorman          Hardcover Fiction
# 4                        Anthony Doerr          Hardcover Fiction
# ..                                 ...                        ...
# 855  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 856                      John Sandford     Combined Print Fiction
# 857                        Kate Morton     Combined Print Fiction
# 858                      Justin Cronin     Combined Print Fiction
# 859                       Mindy Kaling  Combined Print Nonfiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 0     2022-02-06        1982168013                 4.7               3118.0
# 1     2022-02-06        006288834X                 4.6               9966.0
# 2     2022-02-06        B091XWH5T2                 4.2                204.0
# 3     2022-02-06        0593465067                 4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z                 4.5               8792.0
# ..           ...               ...                 ...                  ...
# 855   2012-11-04        B009RFHNB8                 4.5                930.0
# 856   2012-11-04        B0085DP6EY                 4.6               3011.0
# 857   2012-11-04        B009R5Q51W                 4.5               7219.0
# 858   2012-11-04        B009RFGP8K                 4.5               4496.0
# 859   2012-11-04        B0061YXJO8                 4.4               5841.0
#
#      Amazon Price Fic_or_NotFic Main_category
# 0           14.00    Nonfiction       printed
# 1           15.07       Fiction        E-Book
# 2           14.99       Fiction        E-Book
# 3           14.53       Fiction        E-Book
# 4           15.99       Fiction        E-Book
# ..            ...           ...           ...
# 855          0.00       Fiction        E-Book
# 856          9.99       Fiction        E-Book
# 857          0.00       Fiction        E-Book
# 858          0.00       Fiction        E-Book
# 859          0.00    Nonfiction       printed
#
# [822 rows x 13 columns]

# %%
fic_df=df['Fic_or_NotFic'].value_counts()
main_cat_df=df['Main_category'].value_counts()
print(fic_df)
print("")
print(main_cat_df)
# Out:
# Fiction       459
# Nonfiction    363
# Name: Fic_or_NotFic, dtype: int64
#
# E-Book     595
# printed    222
# Audio        5
# Name: Main_category, dtype: int64

# %%
fig, axes = plt.subplots(1,2, figsize=(20, 7))
axes[0].pie(fic_df,labels=fic_df.index,autopct="%1.1f%%",colors=["#37475A","#FEBD69"])
axes[1].pie(main_cat_df,labels=main_cat_df.index,autopct="%1.1f%%",colors=["#37475A","#FEBD69","#11999E"])
axes[0].title.set_text('Distribution of fiction vs non_fiction')
axes[1].title.set_text('Distribution of 3 main category')
plt.tight_layout()

# %%
### What is the Average rated books in 3 main category?

# %%
avg_rate_df=df.groupby('Main_category').mean()['Amazon Rating Total'].sort_values(ascending=False)
avg_rate_df.to_frame()
# Out:
#                Amazon Rating Total
# Main_category
# Audio                 21557.600000
# E-Book                 5596.788235
# printed                3679.887387

# %%
avg_rate_df=df.groupby(['Main_category','Fic_or_NotFic']).mean()['Amazon Rating Total'].unstack()
avg_rate_df.plot(kind='bar', stacked=True)
plt.ylabel("Amazon Rating Total")
plt.title('the Average rated books in 3 main category',fontsize= 15,pad=10,fontweight="bold")
plt.gcf().set_size_inches(20, 10)

# %%
### What is the Average book price in 3 main category?

# %%
df.groupby(['Main_category','Fic_or_NotFic']).mean()['Amazon Price']
# Out:
# Main_category  Fic_or_NotFic
# Audio          Fiction          11.960000
#                Nonfiction        0.000000
# E-Book         Fiction           8.464308
#                Nonfiction        7.089429
# printed        Nonfiction       13.027477
# Name: Amazon Price, dtype: float64

# %%
avg_price_df=df.groupby(['Main_category','Fic_or_NotFic']).mean()['Amazon Price'].unstack()
avg_price_df.plot(kind='bar', stacked=True)
plt.ylabel("Amazon Price")
plt.title('the Average book price in 3 main category',fontsize= 15,pad=10,fontweight="bold")
plt.gcf().set_size_inches(20, 10)

# %%
### Find the some books that is more than in one categories and compare the price

# %%
books=df['Title'].value_counts().head(19).to_frame()
books
# Out:
#                                       Title
# BETRAYAL                                  3
# SAFE HAVEN                                3
# QUIET                                     2
# BOSSYPANTS                                2
# THE INNOCENT                              2
# FALLING                                   2
# THE HOST                                  2
# THE STORYTELLER                           2
# A GAME OF THRONES                         2
# TEAM OF RIVALS                            2
# THE FORGOTTEN                             2
# THE SIGNAL AND THE NOISE                  2
# CARRY ON, WARRIOR                         2
# THE BLACK BOX                             2
# THE GUARDIAN                              2
# LIFE OF PI                                2
# THE IMMORTAL LIFE OF HENRIETTA LACKS      2
# WILD                                      2
# UNSINKABLE                                2

# %%
books_df=pd.concat([df.loc[data_new2['Title']==i] for i in books.index])
books_df=books_df[books_df['Amazon Price']!=0]
books_df.head(5)
# Out:
#      NYT Ranking           ISBN                 Publisher       Title  \
# 137           14  9780593186329                    Dutton    BETRAYAL
# 606           10  9781420124323                Kensington    BETRAYAL
# 739           17  9780440245223   Random House Publishing    BETRAYAL
# 681           12  9781455523542  Grand Central Publishing  SAFE HAVEN
# 702            6  9781455523559  Grand Central Publishing  SAFE HAVEN
#
#               Author           Book Category NYT Pub Date Amazon Product ID  \
# 137    Jonathan Karl    Hardcover Nonfiction   2021-12-19        059318632X
# 606    Fern Michaels          E-Book Fiction   2016-07-24        B004NEW516
# 739   Danielle Steel  Combined Print Fiction   2013-02-24        B005BUG6TI
# 681  Nicholas Sparks  Combined Print Fiction   2013-04-07        1455523542
# 702  Nicholas Sparks  Combined Print Fiction   2013-03-24        147894837X
#
#      Num of Amz Ratings  Amazon Rating Total  Amazon Price Fic_or_NotFic  \
# 137                 4.8               2843.0         21.99    Nonfiction
# 606                 4.6                498.0          4.99       Fiction
# 739                 4.6               2222.0          7.99       Fiction
# 681                 4.7              10178.0          8.99       Fiction
# 702                 4.7              10178.0          6.74       Fiction
#
#     Main_category
# 137       printed
# 606        E-Book
# 739        E-Book
# 681        E-Book
# 702        E-Book

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Title',y='Amazon Price',data=books_df,hue='Main_category',palette=costum_colors,ci=None)
plt.legend(loc='upper right')
plt.xticks(rotation="vertical")
plt.title('Comparing the price of books in 2 categories',fontsize= 15,pad=10,fontweight="bold")
# Out:
# Text(0.5, 1.0, 'Comparing the price of books in 2 categories')

# %%
### What is the Amazon star Ratings of The book with a rank 1 from NYT?

# %%
df.loc[df['NYT Ranking']==1][["Title","Author","NYT Ranking","Num of Amz Ratings"]]
# Out:
#                                 Title  \
# 7                    THE 1619 PROJECT
# 28               THE MIDNIGHT LIBRARY
# 57   LET'S EXPLORE DIABETES WITH OWLS
# 58                     HIDDEN FIGURES
# 86                         RED-HANDED
# 98                            THE HIT
# 293         THE WRONG SIDE OF GOODBYE
# 326                THE SEVENTH PLAGUE
# 343                        TWO BY TWO
# 511          FIRST STAR I SEE TONIGHT
# 586           THE NAZI OFFICER'S WIFE
# 602                         THE TRIAL
# 656                  WALKING DISASTER
# 676                     LOVER AT LAST
# 709                      FROST BURNED
#
#                                                 Author  NYT Ranking  \
# 7    edited  Nikole Hannah-Jones, Caitlin Roper, Il...            1
# 28                                           Matt Haig            1
# 57                                       David Sedaris            1
# 58                                Margot Lee Shetterly            1
# 86                                     Peter Schweizer            1
# 98                                      David Baldacci            1
# 293                                   Michael Connelly            1
# 326                                      James Rollins            1
# 343                                    Nicholas Sparks            1
# 511                           Susan Elizabeth Phillips            1
# 586                    Edith H Beer with Susan Dworkin            1
# 602                 James Patterson with Maxine Paetro            1
# 656                                      Jamie McGuire            1
# 676                                           J R Ward            1
# 709                                    Patricia Briggs            1
#
#      Num of Amz Ratings
# 7                   4.8
# 28                  4.3
# 57                  4.4
# 58                  4.6
# 86                  4.9
# 98                  4.6
# 293                 4.7
# 326                 4.6
# 343                 4.5
# 511                 4.6
# 586                 4.6
# 602                 4.5
# 656                 4.5
# 676                 4.6
# 709                 4.8

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Title',y='Num of Amz Ratings',data=df.loc[df['NYT Ranking']==1],palette=costum_colors)
plt.xticks(rotation="vertical")
plt.title('Amazon Ratings of Books with Rank 1 from NYT',fontsize= 15,pad=10,fontweight="bold")
plt.show()

# %%
### What is the most famous book in this 3 main categories

# %%
three_most_famous_book=df.groupby('Main_category').max()['Amazon Rating Total']
three_most_famous_book
# Out:
# Main_category
# Audio       25110.0
# E-Book     132607.0
# printed     59410.0
# Name: Amazon Rating Total, dtype: float64

# %%
### The distribution of Amazon Rating Total in 3 main categories

# %%
df.groupby(['Main_category']).mean()['Amazon Rating Total']
# Out:
# Main_category
# Audio      21557.600000
# E-Book      5596.788235
# printed     3679.887387
# Name: Amazon Rating Total, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/s3/lg_v6j6j039ckm9ct5vb081w0000gn/T/ipykernel_4830/3889632343.py in <module>
#       1 amz_rating_total=df.groupby(['Main_category']).mean()['Amazon Rating Total']
# ----> 2 amz_rating_total_df.plot(kind='bar', stacked=True)
#       3 plt.ylabel("Amazon Rating Total")
#       4 plt.title('Amazon Rating Total in 3 Main Categories',fontsize= 15,pad=10,fontweight="bold")
#       5 plt.gcf().set_size_inches(20, 10)
#
# NameError: name 'amz_rating_total_df' is not defined

# %%
### 10 most expensive book and their categories

# %%
most_rated_books_df=data_new2.sort_values(by="Amazon Price", ascending=False).head(10)
most_rated_books_df
# Out:
#      NYT Ranking           ISBN                 Publisher  \
# 113           10  9781631492563                 Liveright
# 254           13  9780316296618             Little, Brown
# 132           14  9780593135204                Ballantine
# 112            9  9781982182915          Simon & Schuster
# 620           14  9781455523153  Grand Central Publishing
# 80            19  9781455523153             Grand Central
# 136            7  9781984859501                 Ten Speed
# 632            8  9780307352156          Crown Publishing
# 49            13  9780307352156                  Broadway
# 37             5  9780307476074                   Vintage
#
#                                Title                         Author  \
# 113  THE LYRICS: 1956 TO THE PRESENT                 Paul McCartney
# 254                 THE BOMBER MAFIA               Malcolm Gladwell
# 132                PROJECT HAIL MARY                      Andy Weir
# 112                            PERIL  Bob Woodward and Robert Costa
# 620                    THE FORGOTTEN                 David Baldacci
# 80                     THE FORGOTTEN                 David Baldacci
# 136                   THERE AND BACK                     Jimmy Chin
# 632                            QUIET                     Susan Cain
# 49                             QUIET                     Susan Cain
# 37                              WILD                 Cheryl Strayed
#
#                  Book Category NYT Pub Date Amazon Product ID  \
# 113       Hardcover Nonfiction   2022-01-23        163149256X
# 254       Hardcover Nonfiction   2021-08-29        9124120162
# 132          Hardcover Fiction   2022-01-02        9124125288
# 112       Hardcover Nonfiction   2022-01-23        9124143693
# 620     Combined Print Fiction   2013-05-05        9123978724
# 80      Combined Print Fiction   2022-02-02        9123978724
# 136       Hardcover Nonfiction   2021-12-26        1984859501
# 632  Combined Print Nonfiction   2013-04-28        9123962984
# 49   Combined Print Nonfiction   2022-02-02        9123962984
# 37   Combined Print Nonfiction   2022-02-02        B01NCT5R2J
#
#      Num of Amz Ratings  Amazon Rating Total  Amazon Price
# 113                 4.8               1781.0         90.00
# 254                 5.0                  1.0         89.72
# 132                 5.0                  2.0         79.90
# 112                 2.5                  2.0         64.99
# 620                 4.8                  9.0         64.47
# 80                  4.8                  9.0         64.47
# 136                 4.6                613.0         45.00
# 632                 5.0                  3.0         40.80
# 49                  5.0                  3.0         40.80
# 37                  4.7                  5.0         34.99

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Title',y='Amazon Price',data=most_rated_books_df,hue='Book Category',palette=costum_colors)
plt.legend(loc='upper right')
plt.xticks(rotation="vertical")
plt.title('top 10 most expensive books and their categories',fontsize= 15,pad=10,fontweight="bold")
plt.show()

# %%
### top 10 Publisher

# %%
most_rated_books_df=data_new2.sort_values(by="Amazon Rating Total", ascending=False).head(10)
most_rated_books_df
# Out:
#      NYT Ranking           ISBN                   Publisher  \
# 28             1  9780525559474                      Viking
# 247           15  9781250178602                St. Martin's
# 354           15  9780698185395                   Riverhead
# 29             6  9781501171345            Simon & Schuster
# 296           10  9780062416216               HarperCollins
# 639            9  9780307588364            Crown Publishing
# 90             9  9780307588364                       Crown
# 230           11  9780399590504                Random House
# 530           14  9781501110375                       Atria
# 644           13  9780345803481  Knopf Doubleday Publishing
#
#                          Title          Author           Book Category  \
# 28        THE MIDNIGHT LIBRARY       Matt Haig       Hardcover Fiction
# 247             THE FOUR WINDS  Kristin Hannah       Hardcover Fiction
# 354      THE GIRL ON THE TRAIN   Paula Hawkins          E-Book Fiction
# 29   THE LAST THING HE TOLD ME      Laura Dave       Hardcover Fiction
# 296              THE ALCHEMIST    Paulo Coelho          E-Book Fiction
# 639                  GONE GIRL   Gillian Flynn  Combined Print Fiction
# 90                   GONE GIRL   Gillian Flynn  Combined Print Fiction
# 230                   EDUCATED   Tara Westover    Hardcover Nonfiction
# 530            IT ENDS WITH US  Colleen Hoover          E-Book Fiction
# 644       FIFTY SHADES OF GREY       E L James  Combined Print Fiction
#
#     NYT Pub Date Amazon Product ID  Num of Amz Ratings  Amazon Rating Total  \
# 28    2022-02-06        0525559477                 4.3             132607.0
# 247   2021-09-05        B0882VNQKS                 4.5              90123.0
# 354   2016-12-11        1594634025                 4.1              87948.0
# 29    2022-02-06        1501171348                 4.3              67771.0
# 296   2017-01-15        0062315005                 4.7              67078.0
# 639   2013-04-28        B0088UT8IO                 4.1              63773.0
# 90    2022-02-02        B0088UT8IO                 4.1              63770.0
# 230   2021-09-19        0399590501                 4.7              59410.0
# 530   2016-08-28        1501110365                 4.7              57852.0
# 644   2013-04-28        B007R07BK8                 4.0              56999.0
#
#      Amazon Price
# 28          13.29
# 247          0.00
# 354          7.48
# 29          13.50
# 296          8.89
# 639          0.00
# 90           0.00
# 230         13.00
# 530         12.79
# 644          0.00

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Publisher',y='Amazon Rating Total',data=most_rated_books_df,hue='Book Category',palette=costum_colors)
plt.legend(loc='upper right')
plt.xticks(rotation="vertical")
plt.title('Top 10 Publishers',fontsize= 15,pad=10,fontweight="bold")
plt.show()

# %%
## Which is most popular? Adult Ficton or Adult Non-fiction?

# %%
fic_df=df['Fic_or_NotFic'].value_counts()
print(fic_df)
print("")
# Out:
# Fiction       459
# Nonfiction    363
# Name: Fic_or_NotFic, dtype: int64

# %%
plt.figure(figsize=(20,7))
plt.pie(fic_df,labels=fic_df.index,autopct="%1.1f%%",colors=["#37475A","#FEBD69"])
plt.legend(loc='upper right')
plt.title('Fiction v. Non-fiction',fontsize= 15,pad=10,fontweight="bold")
plt.show()
