# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
books = "output/combined_book.csv"
books_df = pd.read_csv(books)
books_df.head()
# Out:
#    rank primary_isbn13  publisher                         title  \
# 0    11  9781982168018    Gallery                         TASTE
# 1     8  9780062888341     Harper  THE STRANGER IN THE LIFEBOAT
# 2    10  9780385547932  Doubleday                   TO PARADISE
# 3    11  9780593465066     Viking         CALL US WHAT WE CARRY
# 4    12  9781982168438   Scribner             CLOUD CUCKOO LAND
#
#              author              category    pub_date Amazon Product ID  \
# 0     Stanley Tucci  Hardcover Nonfiction  2022-02-06        1982168013
# 1       Mitch Albom     Hardcover Fiction  2022-02-06        006288834X
# 2  Hanya Yanagihara     Hardcover Fiction  2022-02-06        B091XWH5T2
# 3     Amanda Gorman     Hardcover Fiction  2022-02-06        0593465067
# 4     Anthony Doerr     Hardcover Fiction  2022-02-06        B08TRMSR3Z
#
#    Amazon Rating  Amazon Rating Total  Amazon Price
# 0            4.7               3118.0         14.00
# 1            4.6               9966.0         15.07
# 2            4.2                204.0         14.99
# 3            4.9               1794.0         14.53
# 4            4.5               8792.0         15.99

# %%
data_new1 = books_df.copy()                               # Create duplicate of data
data_new1 = data_new1.replace(r'^s*$', float('NaN'), regex = True)  # Replace blanks by NaN
data_new1_df = pd.DataFrame(data_new1)
data_new1_df
# Out:
#       rank primary_isbn13                publisher  \
# 0       11  9781982168018                  Gallery
# 1        8  9780062888341                   Harper
# 2       10  9780385547932                Doubleday
# 3       11  9780593465066                   Viking
# 4       12  9781982168438                 Scribner
# ...    ...            ...                      ...
# 1232    18  9780312547745       St. Martin's Press
# 1233    15  9780399157707            Penguin Group
# 1234    12  9781439152805              Atria Books
# 1235     2  9780345504982  Random House Publishing
# 1236    20  9780307886279         Crown Publishing
#
#                                        title  \
# 0                                      TASTE
# 1               THE STRANGER IN THE LIFEBOAT
# 2                                TO PARADISE
# 3                      CALL US WHAT WE CARRY
# 4                          CLOUD CUCKOO LAND
# ...                                      ...
# 1232  THE WALKING DEAD, RISE OF THE GOVERNOR
# 1233                               MAD RIVER
# 1234                       THE SECRET KEEPER
# 1235                              THE TWELVE
# 1236     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                  author                   category  \
# 0                         Stanley Tucci       Hardcover Nonfiction
# 1                           Mitch Albom          Hardcover Fiction
# 2                      Hanya Yanagihara          Hardcover Fiction
# 3                         Amanda Gorman          Hardcover Fiction
# 4                         Anthony Doerr          Hardcover Fiction
# ...                                 ...                        ...
# 1232  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 1233                      John Sandford     Combined Print Fiction
# 1234                        Kate Morton     Combined Print Fiction
# 1235                      Justin Cronin     Combined Print Fiction
# 1236                       Mindy Kaling  Combined Print Nonfiction
#
#         pub_date Amazon Product ID  Amazon Rating  Amazon Rating Total  \
# 0     2022-02-06        1982168013            4.7               3118.0
# 1     2022-02-06        006288834X            4.6               9966.0
# 2     2022-02-06        B091XWH5T2            4.2                204.0
# 3     2022-02-06        0593465067            4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z            4.5               8792.0
# ...          ...               ...            ...                  ...
# 1232  2012-11-04        B009RFHNB8            4.5                930.0
# 1233  2012-11-04        B0085DP6EY            4.6               3011.0
# 1234  2012-11-04        B009R5Q51W            4.5               7219.0
# 1235  2012-11-04        B009RFGP8K            4.5               4496.0
# 1236  2012-11-04        B0061YXJO8            4.4               5841.0
#
#       Amazon Price
# 0            14.00
# 1            15.07
# 2            14.99
# 3            14.53
# 4            15.99
# ...            ...
# 1232          0.00
# 1233          9.99
# 1234          0.00
# 1235          0.00
# 1236          0.00
#
# [1237 rows x 11 columns]

# %%
data_new2 = data_new1.copy()                          # Create duplicate of data
data_new2.dropna(inplace = True)                      # Remove rows with NaN
data_new2_df = pd.DataFrame(data_new2)
data_new2_df
# Out:
#       rank primary_isbn13                publisher  \
# 0       11  9781982168018                  Gallery
# 1        8  9780062888341                   Harper
# 2       10  9780385547932                Doubleday
# 3       11  9780593465066                   Viking
# 4       12  9781982168438                 Scribner
# ...    ...            ...                      ...
# 1232    18  9780312547745       St. Martin's Press
# 1233    15  9780399157707            Penguin Group
# 1234    12  9781439152805              Atria Books
# 1235     2  9780345504982  Random House Publishing
# 1236    20  9780307886279         Crown Publishing
#
#                                        title  \
# 0                                      TASTE
# 1               THE STRANGER IN THE LIFEBOAT
# 2                                TO PARADISE
# 3                      CALL US WHAT WE CARRY
# 4                          CLOUD CUCKOO LAND
# ...                                      ...
# 1232  THE WALKING DEAD, RISE OF THE GOVERNOR
# 1233                               MAD RIVER
# 1234                       THE SECRET KEEPER
# 1235                              THE TWELVE
# 1236     IS EVERYONE HANGING OUT WITHOUT ME?
#
#                                  author                   category  \
# 0                         Stanley Tucci       Hardcover Nonfiction
# 1                           Mitch Albom          Hardcover Fiction
# 2                      Hanya Yanagihara          Hardcover Fiction
# 3                         Amanda Gorman          Hardcover Fiction
# 4                         Anthony Doerr          Hardcover Fiction
# ...                                 ...                        ...
# 1232  Robert Kirkman and Jay Bonansinga     Combined Print Fiction
# 1233                      John Sandford     Combined Print Fiction
# 1234                        Kate Morton     Combined Print Fiction
# 1235                      Justin Cronin     Combined Print Fiction
# 1236                       Mindy Kaling  Combined Print Nonfiction
#
#         pub_date Amazon Product ID  Amazon Rating  Amazon Rating Total  \
# 0     2022-02-06        1982168013            4.7               3118.0
# 1     2022-02-06        006288834X            4.6               9966.0
# 2     2022-02-06        B091XWH5T2            4.2                204.0
# 3     2022-02-06        0593465067            4.9               1794.0
# 4     2022-02-06        B08TRMSR3Z            4.5               8792.0
# ...          ...               ...            ...                  ...
# 1232  2012-11-04        B009RFHNB8            4.5                930.0
# 1233  2012-11-04        B0085DP6EY            4.6               3011.0
# 1234  2012-11-04        B009R5Q51W            4.5               7219.0
# 1235  2012-11-04        B009RFGP8K            4.5               4496.0
# 1236  2012-11-04        B0061YXJO8            4.4               5841.0
#
#       Amazon Price
# 0            14.00
# 1            15.07
# 2            14.99
# 3            14.53
# 4            15.99
# ...            ...
# 1232          0.00
# 1233          9.99
# 1234          0.00
# 1235          0.00
# 1236          0.00
#
# [860 rows x 11 columns]

# %%
data_new2.columns
# Out:
# Index(['rank', 'primary_isbn13', 'publisher', 'title', 'author', 'category',
#        'pub_date', 'Amazon Product ID', 'Amazon Rating', 'Amazon Rating Total',
#        'Amazon Price'],
#       dtype='object')

# %%
price_rating_col = data_new2.loc[:,['category','Amazon Rating Total','Amazon Price']]
price_rating_col
# Out:
#                        category  Amazon Rating Total  Amazon Price
# 0          Hardcover Nonfiction               3118.0         14.00
# 1             Hardcover Fiction               9966.0         15.07
# 2             Hardcover Fiction                204.0         14.99
# 3             Hardcover Fiction               1794.0         14.53
# 4             Hardcover Fiction               8792.0         15.99
# ...                         ...                  ...           ...
# 1232     Combined Print Fiction                930.0          0.00
# 1233     Combined Print Fiction               3011.0          9.99
# 1234     Combined Print Fiction               7219.0          0.00
# 1235     Combined Print Fiction               4496.0          0.00
# 1236  Combined Print Nonfiction               5841.0          0.00
#
# [860 rows x 3 columns]

# %%
book_group = data_new2.groupby("category")
#book_group_count = book_group["primary_isbn13"].nunique()
avg_price = book_group["Amazon Price"].mean()
avg_rating = book_group["Amazon Rating Total"].mean()
percent_rating = book_group_count/book_group * 100

price_vs_rating = pd.DataFrame({
    "Price Average": avg_price,
    "Rating Average": avg_rating
})
#price_vs_rating.index.name= None
price_vs_rating

price_vs_rating.format({"Price Average":"${:,.2f}",
                        "Rating Average":"${:,.2f}",})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-a0d0d5bf014c> in <module>
#       3 avg_price = book_group["Amazon Price"].mean()
#       4 avg_rating = book_group["Amazon Rating Total"].mean()
# ----> 5 percent_rating = book_group_count/book_group * 100
#       6
#       7 price_vs_rating = pd.DataFrame({
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\arraylike.py in __truediv__(self, other)
#     111     @unpack_zerodim_and_defer("__truediv__")
#     112     def __truediv__(self, other):
# --> 113         return self._arith_method(other, operator.truediv)
#     114
#     115     @unpack_zerodim_and_defer("__rtruediv__")
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _arith_method(self, other, op)
#    4996         lvalues = extract_array(self, extract_numpy=True)
#    4997         rvalues = extract_array(other, extract_numpy=True)
# -> 4998         result = ops.arithmetic_op(lvalues, rvalues, op)
#    4999
#    5000         return self._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     187     else:
#     188         with np.errstate(all="ignore"):
# --> 189             res_values = _na_arithmetic_op(lvalues, rvalues, op)
#     190
#     191     return res_values
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     140
#     141     try:
# --> 142         result = expressions.evaluate(op, left, right)
#     143     except TypeError:
#     144         if is_cmp:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     233         if use_numexpr:
#     234             # error: "None" not callable
# --> 235             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     236     return _evaluate_standard(op, op_str, a, b)
#     237
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118
#     119     if result is None:
# --> 120         result = _evaluate_standard(op, op_str, a, b)
#     121
#     122     return result
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67         _store_test_result(False)
#      68     with np.errstate(all="ignore"):
# ---> 69         return op(a, b)
#      70
#      71
#
# ValueError: operands could not be broadcast together with shapes (8,) (8,2)

# %%
book_group = price_rating_col.groupby("category")
#book_group_count = book_group["primary_isbn13"].nunique()
avg_price = book_group["Amazon Price"].mean()
#avg_rating = book_group["Amazon Rating Total"].mean()

price_vs_rating = pd.DataFrame({
    "Price Average": avg_price,
    #"Rating Average": avg_rating
})
#price_vs_rating.index.name= None
price_vs_rating
# Out:
#                            Price Average
# category
# Audio Fiction                  11.960000
# Audio Nonfiction                0.000000
# Combined Print Fiction          7.719464
# Combined Print Nonfiction      10.554640
# E-Book Fiction                  6.935802
# E-Book Nonfiction               7.130423
# Hardcover Fiction              13.254592
# Hardcover Nonfiction           15.727636

# %%
# Use DataFrame.plot() in order to create a bar chart of the data
price_vs_rating.plot(kind="bar", figsize=(20,3))

# Set a title for the chart
plt.title("Price Average per Aategories")

plt.show()
plt.tight_layout()

# %%
categories = ["E-Book Fiction", "Combined Print Fiction", "E-Book Nonfiction", "Combined Print Nonfiction","Hardcover Nonfiction","Hardcover Fiction", "Audio Fiction", "Audio Nonfiction"]
totals = [212,168,142,125,110,98,4,1]
colors = ["yellow","green","lightblue","orange","red","purple","lightskyblue","lightcoral"]
explode = (0.1,0,0,0,0,0,0,0)

# %%
total_categories =price_rating_col["category"].value_counts()
x_axis= np.arange(len(total_categories))

# %%
total_categories
# Out:
# E-Book Fiction               212
# Combined Print Fiction       168
# E-Book Nonfiction            142
# Combined Print Nonfiction    125
# Hardcover Nonfiction         110
# Hardcover Fiction             98
# Audio Fiction                  4
# Audio Nonfiction               1
# Name: category, dtype: int64

# %%
categories = ["E-Book Fiction", "Combined Print Fiction", "E-Book Nonfiction", "Combined Print Nonfiction","Hardcover Nonfiction","Hardcover Fiction"]
totals = [212,168,142,125,110,98]
colors = ["yellow","lightblue","red","purple","lightskyblue","lightcoral"]
explode = (0.3,0,0,0,0,0)


plt.pie(totals, explode=explode, labels=categories, colors=colors,
        autopct="%1.1f%%", shadow=True, startangle=200)

plt.axis("equal")


plt.show()
